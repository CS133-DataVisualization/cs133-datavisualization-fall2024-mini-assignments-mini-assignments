# %% [markdown]
# Name: Shervan Shahparnia

# %% [markdown]
# ## Use barcharts and heatmaps to visualize patterns in your data
# IGN Game Reviews provide scores from experts for the most recent game releases, ranging from 0 (Disaster) to 10 (Masterpiece).
# <img src="https://i.imgur.com/Oh06Fu1.png">

# %% [markdown]
# ## Load the data
# 1. Read the IGN data file into a dataframe named `ign_scores`.
# 2. Use the `"Platform"` column to label the rows.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

IGN="https://raw.githubusercontent.com/csbfx/advpy122-data/master/ign_scores.csv"
ign_scores = pd.read_csv(IGN)
ign_scores.set_index('Platform', inplace=True)
ign_scores.head()
# Out:
#                     Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast         6.882857           7.511111   6.281818  8.200000
# Game Boy Advance  6.373077           7.507692   6.057143  6.226316
# Game Boy Color    6.272727           8.166667   5.307692  4.500000
# GameCube          6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS      6.670833           7.481818   7.414286  6.614286
#
#                   Platformer    Puzzle       RPG    Racing   Shooter  \
# Platform
# Dreamcast           8.340000  8.088889  7.700000  7.042500  7.616667
# Game Boy Advance    6.970588  6.532143  7.542857  6.657143  6.444444
# Game Boy Color      6.352941  6.583333  7.285714  5.897436  4.500000
# GameCube            6.665714  6.133333  7.890909  6.852632  6.981818
# Nintendo 3DS        7.503448  8.000000  7.719231  6.900000  7.033333
#
#                   Simulation    Sports  Strategy
# Platform
# Dreamcast           7.628571  7.272222  6.433333
# Game Boy Advance    6.928571  6.694444  7.175000
# Game Boy Color      5.900000  5.790698  7.400000
# GameCube            8.028571  7.481319  7.116667
# Nintendo 3DS        7.700000  6.388889  7.900000

# %% [markdown]
# ## Problem 1 - (1 point)
# Use the dataframe ign_scores and write one line of code to determine the highest score received by any kind of games on the Wii platform?

# %%
# prompt: Use the dataframe ign_scores and write one line of code to determine the highest score received by any kind of games on the Wii platform?

ign_scores.loc['Wii'].max()
# Out:
# 7.410344827586206

# %% [markdown]
# ## Problem 2 - (1 point)
# Use the dataframe `ign_scores` to determine which genre has the lowest score for the `PlayStation Vita` platform.

# %%
# prompt: ## Problem 2 - (1 point)
# Use the dataframe `ign_scores` to determine which genre has the lowest score for the `PlayStation Vita` platform.

ign_scores.loc['PlayStation Vita'].idxmin()
# Out:
# 'Simulation'

# %% [markdown]
# ## Problem 3 -  (2 points)
#
#
# Your instructor's favorite video game has been Mario Kart Wii, a racing game released for the Wii platform in 2008. And, IGN agrees with her that it is a great game -- their rating for this game is a whopping 8.9! Inspired by the success of this game, your instructor is considering creating your very own racing game for the Wii platform. Perform the following analyses to help her determine which platform she should focus on.
#
# 1. Create a bar chart that shows the score for *Racing* games, for each platform. Your chart should have one bar for each platform. Provide a meaningful title to the plot.
#
# 2. Based on the bar chart, do you expect a racing game for the **Wii** platform to receive a high rating?  If not, use the pandas to find out from the dataframe `ign_scores` which gaming platform is the best for racing game?

# %%
# Filter scores for the "Racing" genre across all platforms
racing_scores = ign_scores["Racing"]

# Create a bar chart for Racing game scores
plt.figure(figsize=(12, 6))
racing_scores.sort_values(ascending=False).plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Racing Game Scores by Platform (IGN Ratings)")
plt.xlabel("Platform")
plt.ylabel("IGN Score")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# The bar graph shows that the highest should be Xbox One with a score just above 8.

# %%
# Find the platform with the highest Racing game score
best_racing_platform = racing_scores.idxmax()
best_racing_score = racing_scores.max()

print(f"The best platform for Racing games is {best_racing_platform} with a score of {best_racing_score}.")
# Out:
# The best platform for Racing games is Xbox One with a score of 8.163636363636364.

# %% [markdown]
# #### Problem 4 - (2 points)
# Since your instructor's gaming interests are pretty broad, you can help her decide to use the IGN scores to determine the choice of genre and platform.
#
# 1. Create a heatmap using the IGN scores by genre and platform and include the scores in the cells of the heatmap.
# 2. Base on the heatmap, which combination of genre and platform receives the highest average ratings?  Which combination receives the lowest average rankings? Write the answers in a markdown cell.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a heatmap for IGN scores by genre and platform
plt.figure(figsize=(14, 10))
sns.heatmap(ign_scores, annot=True, fmt=".1f", cmap="coolwarm", cbar_kws={'label': 'IGN Score'})
plt.title("IGN Scores Heatmap by Genre and Platform")
plt.xlabel("Genre")
plt.ylabel("Platform")
plt.xticks(rotation=45)
plt.show()

# Find the combination of genre and platform with the highest and lowest average ratings
highest_score = ign_scores.stack().idxmax()
lowest_score = ign_scores.stack().idxmin()
highest_value = ign_scores.max().max()
lowest_value = ign_scores.min().min()

print(f"The highest-rated combination is {highest_score} with a score of {highest_value}.")
print(f"The lowest-rated combination is {lowest_score} with a score of {lowest_value}.")
# Out:
# The highest-rated combination is ('PlayStation 4', 'Simulation') with a score of 9.25.
# The lowest-rated combination is ('Game Boy Color', 'Fighting') with a score of 4.5.

# %% [markdown]
# The highest-rated combination is ('PlayStation 4', 'Simulation') with a score of 9.25.
#
# The lowest-rated combination is ('Game Boy Color', 'Fighting') with a score of 4.5.

# %% [markdown]
# ## Problem 5 - (4 points)
# Use the Pokemon dataset to create a clustermap with color. First, filter the dataframe to only keep data with `Type 1` equals to following values: `Water`, `Normal`, `Grass`, `Bug` and `Psychic`. Annotate the dendrogram using different colors for these five different `Type 1` values. Use `Name` as the index.
#
# pokemon_data is in https://raw.githubusercontent.com/csbfx/advpy122-data/master/Pokemon.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Pokemon dataset (assuming it's already accessible in a DataFrame named pokemon_data)
pokemon_data = pd.read_csv("https://raw.githubusercontent.com/csbfx/advpy122-data/master/Pokemon.csv")

# Filter the dataframe for specific Type 1 values
types_to_include = ['Water', 'Normal', 'Grass', 'Bug', 'Psychic']
filtered_pokemon = pokemon_data[pokemon_data['Type 1'].isin(types_to_include)]

# Set the index to 'Name'
filtered_pokemon.set_index('Name', inplace=True)

# Select numeric columns for clustering
numeric_columns = filtered_pokemon.select_dtypes(include='number')

# Create a clustermap with annotation for different 'Type 1' values
palette = sns.color_palette("husl", len(types_to_include))
type_colors = dict(zip(types_to_include, palette))
row_colors = filtered_pokemon['Type 1'].map(type_colors)

sns.clustermap(
    numeric_columns,
    row_colors=row_colors,
    cmap="magma",
    metric="euclidean",
    method="ward",
    figsize=(12, 8),
    annot=False
)

# Add a legend for 'Type 1' colors
for type_, color in type_colors.items():
    plt.plot([], [], marker="o", color=color, label=type_)
plt.legend(title="Type 1", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.title("Clustermap of Selected Pokemon Types")
plt.show()
