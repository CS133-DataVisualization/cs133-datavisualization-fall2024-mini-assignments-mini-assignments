# %% [markdown]
# ## Assignment 5: Advance pandas
# Let's continue to use the dataset from the wine magazine used in notebook 'Colab_Lec06_advanced-pandas' to practice data transformation, grouping, and sorting.
#
# <img src="https://secure.static.meredith.com/crt/store/covers/magazines/nmo/9826_l.jpg">

# %%
csvurl="https://gist.githubusercontent.com/clairehq/" + \
        "79acab35be50eaf1c383948ed3fd1129/raw/407a02139ae1e134992b90b4b2b8c329b3d73a6a/winemag-data-130k-v2.csv"
import pandas as pd
wine = pd.read_csv(csvurl)
wine.drop(wine.columns[0], axis="columns", inplace=True)
wine.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# #### Question 1: ####
# What is the mean of the points column?

# %%
# Your code here . . .
wine.points.mean()
# Out:
# 88.43403716087269

# %% [markdown]
# #### Question 2: ####
# How many countries are present in this dataset? (Only count each country once)

# %%
# Your code here . . .
wine.country.nunique()
# Out:
# 41

# %% [markdown]
# #### Question 3: ####
# How many times does each country appeared in this dataset? Show each country and the corresponding count (show counts in ascending order)

# %%
# Your code here . . .
wine.groupby('country').country.count().sort_values(ascending=True)
# Out:
# country
# Armenia                       1
# Bosnia and Herzegovina        1
# Slovakia                      1
# Luxembourg                    4
# India                         4
# Switzerland                   4
# Ukraine                       5
# Cyprus                        6
# Macedonia                     6
# Czech Republic                6
# Serbia                        7
# Peru                          8
# Morocco                      11
# Lebanon                      20
# Moldova                      30
# Mexico                       31
# Brazil                       31
# England                      36
# Georgia                      37
# Slovenia                     39
# Turkey                       43
# Croatia                      44
# Uruguay                      61
# Hungary                      61
# Romania                      67
# Bulgaria                     68
# Canada                      108
# Greece                      242
# Israel                      259
# New Zealand                 733
# South Africa                737
# Germany                    1051
# Australia                  1177
# Austria                    1635
# Argentina                  1907
# Chile                      2258
# Portugal                   2963
# Spain                      3409
# Italy                     10005
# France                    11174
# US                        27177
# Name: country, dtype: int64

# %% [markdown]
# #### Question 4: ####
# Create a variable `adjusted_price` containing the adjusted price which is the price subtracted by the average price. *This is called **"centering" transformation** - a method commonly used in the preprocessing step before applying various machine learning algorithms.*

# %%
# Your code here . . .
adjusted_price = wine.price - wine.price.mean()
adjusted_price
# Out:
# 0              NaN
# 1       -20.232932
# 2       -21.232932
# 3       -22.232932
# 4        29.767068
#            ...
# 65494     9.767068
# 65495   -13.232932
# 65496   -15.232932
# 65497    -4.232932
# 65498   -25.232932
# Name: price, Length: 65499, dtype: float64

# %% [markdown]
# #### Question 5: ####
# What is the title of the wine that has the highest points-to-price ratio in the dataset?

# %%
# Your code here . . .
wine['ratio'] = adjusted_price
wine.sort_values(by='ratio', ascending=False)
# Château Pétrus 2014 Pomerol has the highest points-to-price ratio
# Out:
#         country                                        description  \
# 15840    France  The wine is a velvet glove in an iron fist. Th...
# 65352    France  This extravagantly perfumed wine has great jui...
# 1558     France  A massive wine for Margaux, packed with tannin...
# 1575     France  The purest Cabernet Sauvignon fruit, with dark...
# 1571     France  Solid, very structured, packed with dense and ...
# ...         ...                                                ...
# 65252        US  There's a bit of a green bean streak running t...
# 65281  Portugal  This wine is all about black and red berry fru...
# 65284     Chile  Minerally raw aromas brush up against harsh. T...
# 65405   Austria  Intense, crisp acidity shines on this young wi...
# 65486    France  Closed up and firm with a hint of vanilla, hon...
#
#                                           designation  points   price  \
# 15840                                             NaN      96  2500.0
# 65352                                             NaN      97  2000.0
# 1558                                              NaN      98  1900.0
# 1575                                              NaN      96  1300.0
# 1571                                              NaN      96  1200.0
# ...                                               ...     ...     ...
# 65252                                             NaN      87     NaN
# 65281                                    Casa Américo      86     NaN
# 65284                                        Tectonia      86     NaN
# 65405                        Steinagrund Lagenreserve      91     NaN
# 65486  Domaine Long-Depaquit Les Bougnons Premier Cru      90     NaN
#
#                province        region_1          region_2        taster_name  \
# 15840          Bordeaux         Pomerol               NaN         Roger Voss
# 65352          Bordeaux         Pomerol               NaN         Roger Voss
# 1558           Bordeaux         Margaux               NaN         Roger Voss
# 1575           Bordeaux        Pauillac               NaN         Roger Voss
# 1571           Bordeaux  Pessac-Léognan               NaN         Roger Voss
# ...                 ...             ...               ...                ...
# 65252        Washington      Washington  Washington Other       Paul Gregutt
# 65281               Dão             NaN               NaN         Roger Voss
# 65284      Leyda Valley             NaN               NaN  Michael Schachner
# 65405  Wagram-Donauland             NaN               NaN         Roger Voss
# 65486          Burgundy         Chablis               NaN         Roger Voss
#
#       taster_twitter_handle  \
# 15840            @vossroger
# 65352            @vossroger
# 1558             @vossroger
# 1575             @vossroger
# 1571             @vossroger
# ...                     ...
# 65252           @paulgwine
# 65281            @vossroger
# 65284           @wineschach
# 65405            @vossroger
# 65486            @vossroger
#
#                                                    title  \
# 15840                       Château Pétrus 2014  Pomerol
# 65352                       Château Pétrus 2011  Pomerol
# 1558                       Château Margaux 2009  Margaux
# 1575            Château Mouton Rothschild 2009  Pauillac
# 1571             Château Haut-Brion 2009  Pessac-Léognan
# ...                                                  ...
# 65252    Nelms Road 2012 Cabernet Sauvignon (Washington)
# 65281               Seacampo 2013 Casa Américo Red (Dão)
# 65284  Bodega Volcanes de Chile 2014 Tectonia Sauvign...
# 65405  Leth 2010 Steinagrund Lagenreserve Grüner Velt...
# 65486  Albert Bichot 2005 Domaine Long-Depaquit Les B...
#
#                         variety                     winery        ratio
# 15840  Bordeaux-style Red Blend             Château Pétrus  2464.767068
# 65352  Bordeaux-style Red Blend             Château Pétrus  1964.767068
# 1558   Bordeaux-style Red Blend            Château Margaux  1864.767068
# 1575   Bordeaux-style Red Blend  Château Mouton Rothschild  1264.767068
# 1571   Bordeaux-style Red Blend         Château Haut-Brion  1164.767068
# ...                         ...                        ...          ...
# 65252        Cabernet Sauvignon                 Nelms Road          NaN
# 65281            Portuguese Red                   Seacampo          NaN
# 65284           Sauvignon Blanc   Bodega Volcanes de Chile          NaN
# 65405          Grüner Veltliner                       Leth          NaN
# 65486                Chardonnay              Albert Bichot          NaN
#
# [65499 rows x 14 columns]

# %% [markdown]
# #### Question 6: ####
# Create a series `flavor_counts` that contains two values: the number of wines that has the word "tart" in the `description` column and the number of wines that has the word "berries" in the `description` column. The index of the Series should be "Tart" and "Berries" for the corresponding values.

# %%
# Look for the word "tart", not case sensitive, not a substring of another word.
# Same applies to the word "berries"
# Your code here . . .

tartTemp = wine.loc[wine.description.map(lambda x: "tart" in x), "description"].count() #row, col
tartBerries = wine.loc[wine.description.map(lambda x: "berries" in x), "description"].count()
flavor_counts = pd.Series([tartTemp, tartBerries], index=["Tart", "Berries"], name="Count")
flavor_counts
# Out:
# Tart       4172
# Berries    3503
# Name: Count, dtype: int64

# %% [markdown]
# #### Question 7: ####
# Let's convert the points into simple star ratings. A score of 90 or higher counts as 3 stars, a score of at least 80 but less than 90 is 2 stars. Any other score is 1 star.
#
# Also, any wines from France should automatically get 3 stars, regardless of points.
#
# Add this new column `star_ratings` to the dataframe with the number of stars for each wine in the dataset.

# %%
# Your code here . . .
def rating(x):
  if x >= 90:
    return 3
  elif x >= 80:
    return 2
  else:
    return 1

star_ratings = wine.points.map(rating)
wine["star_ratings"] = star_ratings
wine.loc[wine.country == "France", "star_ratings"] = 3
wine
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 65494     France  Made from young vines from the Vaulorent porti...
# 65495  Australia  This is a big, fat, almost sweet-tasting Caber...
# 65496         US  Much improved over the unripe 2005, Fritz's 20...
# 65497         US  This wine wears its 15.8% alcohol better than ...
# 65498      Spain  A unique take on Manzanilla Sherry, which is o...
#
#                               designation  points  price           province  \
# 0                            Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                Avidagos      87   15.0              Douro
# 2                                     NaN      87   14.0             Oregon
# 3                    Reserve Late Harvest      87   13.0           Michigan
# 4      Vintner's Reserve Wild Child Block      87   65.0             Oregon
# ...                                   ...     ...    ...                ...
# 65494              Fourchaume Premier Cru      90   45.0           Burgundy
# 65495                                 NaN      90   22.0    South Australia
# 65496                              Estate      90   20.0         California
# 65497                            Block 24      90   31.0         California
# 65498                          Manzanilla      90   10.0          Andalucia
#
#                   region_1           region_2         taster_name  \
# 0                     Etna                NaN       Kerin O’Keefe
# 1                      NaN                NaN          Roger Voss
# 2        Willamette Valley  Willamette Valley        Paul Gregutt
# 3      Lake Michigan Shore                NaN  Alexander Peartree
# 4        Willamette Valley  Willamette Valley        Paul Gregutt
# ...                    ...                ...                 ...
# 65494              Chablis                NaN          Roger Voss
# 65495         McLaren Vale                NaN      Joe Czerwinski
# 65496     Dry Creek Valley             Sonoma                 NaN
# 65497          Napa Valley               Napa                 NaN
# 65498                Jerez                NaN   Michael Schachner
#
#       taster_twitter_handle  \
# 0              @kerinokeefe
# 1                @vossroger
# 2               @paulgwine
# 3                       NaN
# 4               @paulgwine
# ...                     ...
# 65494            @vossroger
# 65495                @JoeCz
# 65496                   NaN
# 65497                   NaN
# 65498           @wineschach
#
#                                                    title             variety  \
# 0                      Nicosia 2013 Vulkà Bianco  (Etna)         White Blend
# 1          Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 2          Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3      St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4      Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# ...                                                  ...                 ...
# 65494  William Fèvre 2005 Fourchaume Premier Cru  (Ch...          Chardonnay
# 65495    Tapestry 2005 Cabernet Sauvignon (McLaren Vale)  Cabernet Sauvignon
# 65496  Fritz 2006 Estate Sauvignon Blanc (Dry Creek V...     Sauvignon Blanc
# 65497       Hendry 2004 Block 24 Primitivo (Napa Valley)           Primitivo
# 65498  Bodegas Dios Baco S.L. NV Manzanilla Sherry (J...              Sherry
#
#                        winery      ratio  star_ratings
# 0                     Nicosia        NaN             2
# 1         Quinta dos Avidagos -20.232932             2
# 2                   Rainstorm -21.232932             2
# 3                  St. Julian -22.232932             2
# 4                Sweet Cheeks  29.767068             2
# ...                       ...        ...           ...
# 65494           William Fèvre   9.767068             3
# 65495                Tapestry -13.232932             3
# 65496                   Fritz -15.232932             3
# 65497                  Hendry  -4.232932             3
# 65498  Bodegas Dios Baco S.L. -25.232932             3
#
# [65499 rows x 15 columns]

# %% [markdown]
# #### Question 8: ####
# Who are the most common wine reviewers in the dataset? Create a Series whose index is the taster_twitter_handle category from the dataset, and whose values count how many reviews each person wrote.

# %%
# Your code here . . .
reviewCount = wine.groupby('taster_twitter_handle').taster_twitter_handle.count().sort_values(ascending=False)
reviewSeries = pd.Series(reviewCount, name="Count")
reviewSeries
# Out:
# taster_twitter_handle
# @vossroger          13045
# @wineschach          7752
# @kerinokeefe         5313
# @paulgwine           4851
# @vboone              4696
# @mattkettmann        3035
# @JoeCz               2605
# @wawinereport        2358
# @gordone_cellars     2032
# @AnneInVino          1769
# @laurbuzz             938
# @suskostrzewa         593
# @worldwineguys        465
# @bkfiona               11
# @winewchristina         4
# Name: Count, dtype: int64

# %% [markdown]
# #### Question 9: ####
# What combination of countries and varieties are most common? Create a Series whose index is a MultiIndexof {country, variety} pairs. For example, a pinot noir produced in the US should map to {"US", "Pinot Noir"}. Sort the values in the Series in descending order based on wine count.

# %%
# Your code here . . .

wine.groupby(['country', 'variety']).variety.count().sort_values(ascending=False)
# Out:
# country  variety
# US       Pinot Noir                  4918
#          Cabernet Sauvignon          3649
#          Chardonnay                  3412
# France   Bordeaux-style Red Blend    2380
# Italy    Red Blend                   1870
#                                      ...
#          Torbato                        1
#          Vespaiolo                      1
#          Vespolina                      1
#          Vitovska                       1
# Uruguay  Tempranillo-Tannat             1
# Name: variety, Length: 1304, dtype: int64

# %% [markdown]
# #### Question 10 #####
# Create a Series whose index is reviewers and whose values is the average score given out by that reviewer. Hint: you will need the `taster_name` and `points` columns.

# %%
# Your code here . . .

wine.groupby("taster_name").points.mean()
# Out:
# taster_name
# Alexander Peartree    86.014286
# Anna Lee C. Iijima    88.380506
# Anne Krebiehl MW      90.587903
# Carrie Dykes          86.644444
# Christina Pickard     89.500000
# Fiona Adams           87.090909
# Jeff Jenssen          88.273504
# Jim Gordon            88.604331
# Joe Czerwinski        88.519770
# Kerin O’Keefe         88.827969
# Lauren Buzzeo         87.831557
# Matt Kettmann         90.021087
# Michael Schachner     86.904541
# Mike DeSimone         89.030303
# Paul Gregutt          89.095032
# Roger Voss            88.678957
# Sean P. Sullivan      88.666243
# Susan Kostrzewa       86.408094
# Virginie Boone        89.229557
# Name: points, dtype: float64
